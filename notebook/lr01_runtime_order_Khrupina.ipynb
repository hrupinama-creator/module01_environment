# %% [markdown]
# # Лабораторная работа 1.2 уровень
# Цель: восстановить порядок ячеек и проверить notebook после перезапуска.

# %% [markdown]
# Мини-эксперемент:
# Сначала попробуем создать код,в котором ячейки будут выполняться в ошибочном порядке,затем выполним данное действия в правильном порядке.

# %% [markdown]
# ## Ошибочный вариант
# Сначала выполним ячейку с print до создания переменной исируйте ошибку.

# %%
print(project_title)
# Out:
# Corpus Mini Lab

# %%
project_title = "Corpus Mini Lab"

# %% [markdown]
# ##Переменная не выводится,выдает ошибку,так как ячейки выполняются в неправильном порядке.Сначала переменная должна быть введена в код,чтобы в дальнейшем ее выводить.При данном выполнении вывод происходит несуществующей переменной.

# %% [markdown]
# Правильный вариант
# Выполним запуск ячеек,чтобы получить результат.

# %%
project_title = "Corpus lab"
print(project_title)
# Out:
# Corpus lab

# %% [markdown]
# Итог:Команда print(project_title) выполнена без ошибок,так как ячейки выполнились в правильном порядке.Текст успешно выведен на экран.

# %% [markdown]
# Вывод о состоянии:В ошибочном варианте ячейка с выводом переменной project_title была запущена до ее ввода,что привело к ошибке.Это подтвердило,что для корректной работы ячейки должны выполняться в определенном порядке.
